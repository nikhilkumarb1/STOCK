# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

# %%
# Load your stock price data
# Replace 'netflix.csv' with your dataset file
data = pd.read_csv('netflix.csv')
data = data['Close'].values.reshape(-1, 1)

# %%
# Normalize the data
scaler = MinMaxScaler()
data = scaler.fit_transform(data)

# %%
# Split the data into training and testing sets
train_size = int(len(data) * 0.80)
train_data = data[:train_size]
test_data = data[train_size:]

# %%
# Function to create sequences for LSTM
def create_sequences(data, sequence_length):
    X, y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data[i:i+sequence_length])
        y.append(data[i+sequence_length])
    return np.array(X), np.array(y)

# %%
sequence_length = 10  # You can adjust this parameter
X_train, y_train = create_sequences(train_data, sequence_length)
X_test, y_test = create_sequences(test_data, sequence_length)

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Train the model
model.fit(X_train, y_train, epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 122/122 [==============================] - 5s 12ms/step - loss: 5.8554e-04
# Epoch 2/20
# 122/122 [==============================] - 2s 19ms/step - loss: 2.5636e-05
# Epoch 3/20
# 122/122 [==============================] - 2s 12ms/step - loss: 2.5184e-05
# Epoch 4/20
# 122/122 [==============================] - 1s 11ms/step - loss: 2.4545e-05
# Epoch 5/20
# 122/122 [==============================] - 1s 11ms/step - loss: 2.5371e-05
# Epoch 6/20
# 122/122 [==============================] - 1s 11ms/step - loss: 2.3970e-05
# Epoch 7/20
# 122/122 [==============================] - 1s 11ms/step - loss: 2.4389e-05
# Epoch 8/20
# 122/122 [==============================] - 1s 11ms/step - loss: 2.8073e-05
# Epoch 9/20
# 122/122 [==============================] - 1s 11ms/step - loss: 2.2794e-05
# Epoch 10/20
# 122/122 [==============================] - 2s 16ms/step - loss: 2.6939e-05
# Epoch 11/20
# 122/122 [==============================] - 2s 16ms/step - loss: 2.6277e-05
# Epoch 12/20
# 122/122 [==============================] - 1s 12ms/step - loss: 2.0194e-05
# Epoch 13/20
# 122/122 [==============================] - 1s 11ms/step - loss: 2.0964e-05
# Epoch 14/20
# 122/122 [==============================] - 1s 11ms/step - loss: 2.2142e-05
# Epoch 15/20
# 122/122 [==============================] - 1s 11ms/step - loss: 2.1923e-05
# Epoch 16/20
# 122/122 [==============================] - 1s 11ms/step - loss: 1.8665e-05
# Epoch 17/20
# 122/122 [==============================] - 1s 11ms/step - loss: 1.6370e-05
# Epoch 18/20
# 122/122 [==============================] - 2s 13ms/step - loss: 1.5949e-05
# Epoch 19/20
# 122/122 [==============================] - 2s 18ms/step - loss: 1.6947e-05
# Epoch 20/20
# 122/122 [==============================] - 1s 12ms/step - loss: 1.6596e-05

# %%
# Make predictions
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
y_test = scaler.inverse_transform(y_test)
# Out:
# 31/31 [==============================] - 1s 4ms/step

# %%
# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(y_test, label='Actual Stock Price')
plt.plot(predictions, label='Predicted Stock Price')
plt.legend()
plt.show()
